# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt


shapefile_path = r"C:\Users\Tanmay\Desktop\Tanmay.Project\StateBoundary"
temperature_csv= r"C:\Users\Tanmay\Desktop\Tanmay.Project\temperature.csv"



fig, ax = plt.subplots(1, 1, figsize=(3, 1))
ax.set_title('Monthly Choropleth of India based on Average Temperatue of different states (2022)', fontsize=16)
ax.axis('off')  
plt.show()


df0 = pd.read_csv(temperature_csv)
df0.rename(columns={df0.columns[0] : 'state'},inplace =True)
df = df0.sort_values(by='state', ascending=True)

df["state"] = df["state"].apply(lambda x: x.upper())


india_map = gpd.read_file(shapefile_path)
gdf2 = india_map.sort_values(by='state', ascending=True)

#Adjusting dataframe values to match gdf
df.iloc[12, df.columns.get_loc('state')] = 'JAMMU & KASHMIR'
df.iloc[25, df.columns.get_loc('state')] = 'RAJASTHAN'
df.iloc[1, df.columns.get_loc('state')] = 'ANDHRA PRADESH'
df.iloc[8,df.columns.get_loc('July')] = 26.71

merged_gdf = gdf2.merge(df, on='state')

#Jan
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column='Jan', 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                         cmap='RdBu_r',  
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('January', fontsize=16)
ax.axis('off')  
plt.show()
 #Feb
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="Feb", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                          cmap='RdBu_r',  
                         missing_kwds={
                         "color": "lightgrey",
                         "label": "No Data" 
                         
                         
                         })
ax.set_title('February', fontsize=16)
ax.axis('off')  
plt.show()
 
 #Mar
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="Mar", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                          cmap='RdBu_r' , 
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('March', fontsize=16)
ax.axis('off')  
plt.show()

#apr
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="Apr", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                          cmap='RdBu_r',  
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('April', fontsize=16)
ax.axis('off')  
plt.show()

#may
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="May", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                          cmap='RdBu_r',  
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('May', fontsize=16)
ax.axis('off')  
plt.show()

#June
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="June", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                         cmap='RdBu_r',  
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('June', fontsize=16)
ax.axis('off')  
plt.show()

#July
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  



# Plot the map
choropleth = merged_gdf.plot(
    column="July", 
    ax=ax, 
    legend=True,
    cmap='RdBu_r',  
    missing_kwds={
        "color": "lightgrey",
        "label": "No Data"
    }
)

ax.set_title('July', fontsize=16)
ax.axis('off')  

# Show the plot
plt.show()

#Aug
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="Aug", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                          cmap='RdBu_r',  
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('August', fontsize=16)
ax.axis('off')  
plt.show()

#sep
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="Sep", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                         cmap='RdBu_r',  
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('September', fontsize=16)
ax.axis('off')  
plt.show()

#oct
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="Oct", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                          cmap='RdBu_r',  
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('October', fontsize=16)
ax.axis('off')  
plt.show()

#Nov
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="Nov", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                          cmap='RdBu_r',  
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('November', fontsize=16)
ax.axis('off')  
plt.show()

#Dec
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
gdf2.boundary.plot(ax=ax, linewidth=1, color='black')  # Plot boundaries for clarity
choropleth = merged_gdf.plot(column="Dec", 
                         ax=ax, 
                         legend=True,
                         legend_kwds={
                         "label": "Average Temperature (°C)",  # Legend title
                         "orientation": "vertical",  # Orientation of the color bar (horizontal/vertical)
                         "shrink": 0.8},
                                                  cmap='RdBu_r', 
                         missing_kwds={
                             "color": "lightgrey",
                             "label": "No Data"
                         })
ax.set_title('Descember', fontsize=16)
ax.axis('off')  
plt.show()
